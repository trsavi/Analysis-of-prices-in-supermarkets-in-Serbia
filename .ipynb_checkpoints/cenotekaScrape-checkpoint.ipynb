# %%
# Importing packages
#from selenium import webdriver
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
#import  sys

# %%
url = 'https://cenoteka.rs'

# %%
# Find all categories
def find_categories():
    page = requests.get(url)
    soup = bs(page.content, 'html.parser')
    categories = []
    classes = soup.find(class_='nav navbar-nav mr-auto')
    for i in classes.find_all(class_='nav-item dropdown'):
        categories.append(i.find('a')['href'])

    categories = categories[1:]
    return categories

# %%
# Find all links in categories
def get_links(category):
    page = requests.get(url+category)
    soup = bs(page.content, 'html.parser')
    links = []
    divs = soup.find_all(class_='cat-list-item')
    for a in divs:
        links.append(a.find('a')['href'])
    return links

# %%
def scrape_page(soup):
    
    shops_class = soup.find("div", {"id": "products"})
    #category = soup.find(class_='section-title col-12').get_text()
    #print(shops_class)
    prices_list = []
    names_list = []
    product_dict = {}
    for shop in shops_class.find_all(True, {'class':['border-gray d-flex flex-nowrap flex-row article-row col-6 col-md-12 p-0', 'border-gray d-flex flex-nowrap flex-row article-row col-6 col-md-12 p-0 odd']}):
        names=shop.find_all(class_='article-hover article-name flex-full-height-center border-gray-right p-1')
        #print(names)
        for name in names:
            
            names_list.append(name.get_text())
            names_list = [item.strip() for item in names_list if str(item)]
            #print(names_list)
        prices = shop.find_all(class_='price')
        for price in prices:
            prices_list.append(price.get_text())
            prices_list = [item.strip() for item in prices_list if str(item)]
        
        product_dict[names_list[0]] = prices_list
        prices_list = []
        names_list = []
        
    return product_dict

# %%
dataframe_full = pd.DataFrame()
categories = find_categories()
#print(categories)
# Iterate through each category and scrape links
for category in categories:
    links = get_links(category)
    
    for link in links:
        #print(link)
        page = requests.get(url+link)
        soup = bs(page.content, 'html.parser')
        try:
            pages = soup.find(class_="paginator-navigation")
            page_num = pages.find_all(class_="page-item")[-2]
            page_num = int(page_num.get_text())
            
            for i in range(1,page_num+1):
                #print(i)
                dataframe = pd.DataFrame()
                page = requests.get(url+link+'?page='+str(i))
                soup = bs(page.content, 'html.parser')
                product = scrape_page(soup)
                #print(product)
                dataframe = dataframe.from_dict(product, orient='index', columns= ['IDEA','MAXI','UNIVEREXPORT','TEMPO','DIS','RODA','LIDL'])
                #print(dataframe)
                dataframe_full = dataframe_full.append(dataframe)

        except:
            page = requests.get(url+link)
            soup = bs(page.content, 'html.parser')
            #print('Exception RAISED')
            #print(soup)
            product = scrape_page(soup)
            try:
                dataframe = dataframe.from_dict(product, orient='index', columns= ['IDEA','MAXI','UNIVEREXPORT','TEMPO','DIS','RODA','LIDL'])
                #print(dataframe)
                dataframe_full = dataframe_full.append(dataframe)
            except:
                pass

# %%
dataframe_full
# Out:
#                                            IDEA    MAXI UNIVEREXPORT   TEMPO  \
# Brašno DANUBIUS heljdin mešani hleb 1kg  294,99  294,99       224,99  274,99
# Brašno DANUBIUS meko T-400 1kg            84,70   84,70        84,70   84,70
# Brašno DANUBIUS oštro T-400 1kg           97,99       -        94,99   92,99
# Brašno DANUBIUS T-500 1kg                 78,65   78,65        78,60   78,65
# Brašno DANUBIUS T-850 900g                76,99   94,99        69,99   84,99
# Brašno DANUBIUS za integralni hleb 900g   91,99   91,99        69,99   82,99
# Brašno DANUBIUS za pizzu 5kg             132,99       -       109,99  133,99
# Brašno DANUBIUS za ražani hleb 900g       85,99  112,99        89,99   94,99
# Brašno FIDELINKA meko T-400 1kg               -       -            -       -
# Brašno FIDELINKA T-500 1kg                78,65       -            -       -
# Brašno KIKINDSKI MLIN T-400 1kg           84,70       -        74,99       -
# Brašno KIKINDSKI MLIN T-500 1kg           69,99       -        78,60       -
# Brašno SENTELLA T-400 glatko 1kg          84,70   84,70        84,70   84,70
# Brašno SENTELLA T-400 glatko 5kg              -       -       423,50       -
# Brašno SENTELLA T-400 oštro 1kg          114,99       -        94,99       -
# Brašno SENTELLA T-500 1kg                 78,65   78,65        78,60   78,65
# Brašno STARI MLINAR T-400 glatko 1kg      84,70   84,70            -   84,70
# Brašno STARI MLINAR T-500 1kg             78,65   78,65            -   78,65
# Brašno VEGA kukuruzno integralno 1kg          -  199,99       174,99  189,99
# Kukuruzno brašno CORN 500g                89,99  112,99        87,99   96,99
# Kukuruzno brašno STARI MLINAR 500g       117,99  117,99        87,99   92,99
# Kukuruzno brašno CASTELLO 500g                -       -            -       -
# Griz C pšenični dečiji C 200g             59,99   85,99        72,99   71,99
# Griz C pšenični dečiji C 400g            139,99  109,99       136,99  109,99
# Griz CORN kukuruzni 500g                 107,99       -       103,99       -
# Griz FLORY pšenični 200g                  76,99       -        67,99       -
# Griz FLORY pšenični 400g                 164,99       -       131,99       -
# Griz STARI MLINAR kukuruzni 500g         116,99  112,99       107,99   97,99
# Kukuruzni griz CASTELLO 500g                  -       -            -       -
# Palenta CORN 500g                        167,99  176,99       129,99  161,99
# Palenta DIVELLA 500g                          -       -       214,99  197,99
# Palenta DR.OETKER 500g                   116,99  114,99       114,99  109,99
# Palenta FLORIDA BEL Abc 500g             105,99  146,99       101,99  124,99
# Proja DR.OETKER 350g                     179,99  179,99       161,99  169,99
# Kukuruzno brašno ABC 500g                124,99  104,99            -   97,99
# Brašno VEGA pšenično integralno 1kg           -  127,99       114,99  114,99
#
#                                             DIS    RODA    LIDL
# Brašno DANUBIUS heljdin mešani hleb 1kg       -  274,99       -
# Brašno DANUBIUS meko T-400 1kg            84,69   79,99       -
# Brašno DANUBIUS oštro T-400 1kg           81,99   92,99       -
# Brašno DANUBIUS T-500 1kg                 78,59   78,65       -
# Brašno DANUBIUS T-850 900g                84,99   76,99       -
# Brašno DANUBIUS za integralni hleb 900g   83,99   82,99       -
# Brašno DANUBIUS za pizzu 5kg              89,99  132,99       -
# Brašno DANUBIUS za ražani hleb 900g       99,99   85,99       -
# Brašno FIDELINKA meko T-400 1kg               -   77,99       -
# Brašno FIDELINKA T-500 1kg                    -   78,65       -
# Brašno KIKINDSKI MLIN T-400 1kg           78,39   84,70       -
# Brašno KIKINDSKI MLIN T-500 1kg           71,79   69,99       -
# Brašno SENTELLA T-400 glatko 1kg          66,49   84,70       -
# Brašno SENTELLA T-400 glatko 5kg         326,69       -       -
# Brašno SENTELLA T-400 oštro 1kg           80,99  112,99       -
# Brašno SENTELLA T-500 1kg                 62,89   78,65       -
# Brašno STARI MLINAR T-400 glatko 1kg      72,59   84,70       -
# Brašno STARI MLINAR T-500 1kg             66,99   78,65       -
# Brašno VEGA kukuruzno integralno 1kg     176,99       -       -
# Kukuruzno brašno CORN 500g                97,99   89,99       -
# Kukuruzno brašno STARI MLINAR 500g        79,99   97,99       -
# Kukuruzno brašno CASTELLO 500g                -       -   59,99
# Griz C pšenični dečiji C 200g                 -   59,99       -
# Griz C pšenični dečiji C 400g            132,99  129,99  109,99
# Griz CORN kukuruzni 500g                  91,99   94,99       -
# Griz FLORY pšenični 200g                      -   69,99       -
# Griz FLORY pšenični 400g                      -  152,99       -
# Griz STARI MLINAR kukuruzni 500g          89,99  102,99       -
# Kukuruzni griz CASTELLO 500g                  -       -   64,99
# Palenta CORN 500g                        169,99  161,99       -
# Palenta DIVELLA 500g                          -       -       -
# Palenta DR.OETKER 500g                        -  109,99       -
# Palenta FLORIDA BEL Abc 500g             109,99  105,99       -
# Proja DR.OETKER 350g                     158,99  169,99       -
# Kukuruzno brašno ABC 500g                     -   97,99       -
# Brašno VEGA pšenično integralno 1kg       99,99       -       -

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Palenta CORN 500g to Brašno VEGA pšenično integralno 1kg
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IDEA          7 non-null      object
#  1   MAXI          7 non-null      object
#  2   UNIVEREXPORT  7 non-null      object
#  3   TEMPO         7 non-null      object
#  4   DIS           7 non-null      object
#  5   RODA          7 non-null      object
#  6   LIDL          7 non-null      object
# dtypes: object(7)
# memory usage: 448.0+ bytes
